# %%
import numpy as np
from kma_method import KomodoMlipirAlgorithm

# %%
def fitness_function(x):
    return 4*x[0]**2 - 2.1*x[0]**4 + 1/3*x[0]**6 + x[0]*x[1] - 4*x[1]**2 + 4*x[1]**4

# %%
space_search = {
    'x1':[-5,5],
    'x2':[-5,5]
}

# %%
kma = KomodoMlipirAlgorithm(20,0.5,0.1,fitness_function,space_search,max_iter=100,problem="minimize")

# %%
kma.optimize()
# Out:
# Betina kawin dengan jantan besar.
# Generasi 1: Best Fitness = 0.6703083250571567, Best Solution = [-0.07442399  1.07578836]
# Betina kawin dengan jantan besar.
# Generasi 2: Best Fitness = 0.4521671065739133, Best Solution = [ 1.45006482 -0.59330616]
# Betina kawin dengan jantan besar.
# Generasi 3: Best Fitness = -0.9003864774022448, Best Solution = [0.09277136 0.69986156]
# Betina melakukan parthenogenesis.
# Generasi 4: Best Fitness = -0.9003864774022448, Best Solution = [0.09277136 0.69986156]
# Betina kawin dengan jantan besar.
# Generasi 5: Best Fitness = -0.9003864774022448, Best Solution = [0.09277136 0.69986156]
# Betina melakukan parthenogenesis.
# Generasi 6: Best Fitness = -0.9003864774022448, Best Solution = [0.09277136 0.69986156]
# Betina melakukan parthenogenesis.
# Generasi 7: Best Fitness = -0.9003864774022448, Best Solution = [0.09277136 0.69986156]
# Betina melakukan parthenogenesis.
# Generasi 8: Best Fitness = -0.9003864774022448, Best Solution = [0.09277136 0.69986156]
# Betina kawin dengan jantan besar.
# Generasi 9: Best Fitness = -0.9003864774022448, Best Solution = [0.09277136 0.69986156]
# Betina kawin dengan jantan besar.
# Generasi 10: Best Fitness = -1.005641888968967, Best Solution = [ 0.16973859 -0.73185425]
# Betina melakukan parthenogenesis.
# Generasi 11: Best Fitness = -1.005641888968967, Best Solution = [ 0.16973859 -0.73185425]
# Betina kawin dengan jantan besar.
# Generasi 12: Best Fitness = -1.005641888968967, Best Solution = [ 0.16973859 -0.73185425]
# Betina kawin dengan jantan besar.
# Generasi 13: Best Fitness = -1.005641888968967, Best Solution = [ 0.16973859 -0.73185425]
# Betina kawin dengan jantan besar.
# Generasi 14: Best Fitness = -1.005641888968967, Best Solution = [ 0.16973859 -0.73185425]
# Betina kawin dengan jantan besar.
# Generasi 15: Best Fitness = -1.005641888968967, Best Solution = [ 0.16973859 -0.73185425]
# Betina kawin dengan jantan besar.
# Generasi 16: Best Fitness = -1.005641888968967, Best Solution = [ 0.16973859 -0.73185425]
# Betina kawin dengan jantan besar.
# Generasi 17: Best Fitness = -1.0263619915825375, Best Solution = [-0.09482886  0.68739492]
# Betina kawin dengan jantan besar.
# Generasi 18: Best Fitness = -1.0263619915825375, Best Solution = [-0.09482886  0.68739492]
# Betina melakukan parthenogenesis.
# Generasi 19: Best Fitness = -1.0263619915825375, Best Solution = [-0.09482886  0.68739492]
# Betina kawin dengan jantan besar.
# Generasi 20: Best Fitness = -1.0263619915825375, Best Solution = [-0.09482886  0.68739492]
# Betina melakukan parthenogenesis.
# Generasi 21: Best Fitness = -1.0263619915825375, Best Solution = [-0.09482886  0.68739492]
# Betina melakukan parthenogenesis.
# Generasi 22: Best Fitness = -1.0263619915825375, Best Solution = [-0.09482886  0.68739492]
# Betina melakukan parthenogenesis.
# Generasi 23: Best Fitness = -1.0263619915825375, Best Solution = [-0.09482886  0.68739492]
# Betina kawin dengan jantan besar.
# Generasi 24: Best Fitness = -1.0263619915825375, Best Solution = [-0.09482886  0.68739492]
# Betina melakukan parthenogenesis.
# Generasi 25: Best Fitness = -1.0263619915825375, Best Solution = [-0.09482886  0.68739492]
# Betina melakukan parthenogenesis.
# Generasi 26: Best Fitness = -1.0263619915825375, Best Solution = [-0.09482886  0.68739492]
# Betina melakukan parthenogenesis.
# Generasi 27: Best Fitness = -1.0284459850683212, Best Solution = [-0.07185619  0.69601153]
# Betina kawin dengan jantan besar.
# Generasi 28: Best Fitness = -1.0287812921706507, Best Solution = [-0.07131235  0.69775824]
# Betina melakukan parthenogenesis.
# Generasi 29: Best Fitness = -1.0310543552905087, Best Solution = [-0.09216424  0.70453362]
# Betina kawin dengan jantan besar.
# Generasi 30: Best Fitness = -1.031160631790098, Best Solution = [-0.0820581   0.70681997]
# Betina kawin dengan jantan besar.
# Generasi 31: Best Fitness = -1.031160631790098, Best Solution = [-0.0820581   0.70681997]
# Betina melakukan parthenogenesis.
# Generasi 32: Best Fitness = -1.031160631790098, Best Solution = [-0.0820581   0.70681997]
# Betina melakukan parthenogenesis.
# Generasi 33: Best Fitness = -1.0315311951172308, Best Solution = [-0.08854465  0.70924001]
# Betina kawin dengan jantan besar.
# Generasi 34: Best Fitness = -1.0315311951172308, Best Solution = [-0.08854465  0.70924001]
# Betina melakukan parthenogenesis.
# Generasi 35: Best Fitness = -1.0315311951172308, Best Solution = [-0.08854465  0.70924001]
# Betina melakukan parthenogenesis.
# Generasi 36: Best Fitness = -1.0315311951172308, Best Solution = [-0.08854465  0.70924001]
# Betina kawin dengan jantan besar.
# Generasi 37: Best Fitness = -1.0315311951172308, Best Solution = [-0.08854465  0.70924001]
# Betina kawin dengan jantan besar.
# Generasi 38: Best Fitness = -1.031593342570998, Best Solution = [-0.09285148  0.71273047]
# Betina melakukan parthenogenesis.
# Generasi 39: Best Fitness = -1.0316174707088204, Best Solution = [-0.09142523  0.71235612]
# Betina melakukan parthenogenesis.
# Generasi 40: Best Fitness = -1.0316174707088204, Best Solution = [-0.09142523  0.71235612]
# Betina melakukan parthenogenesis.
# Generasi 41: Best Fitness = -1.0316174707088204, Best Solution = [-0.09142523  0.71235612]
# Betina melakukan parthenogenesis.
# Generasi 42: Best Fitness = -1.0316174707088204, Best Solution = [-0.09142523  0.71235612]
# Betina melakukan parthenogenesis.
# Generasi 43: Best Fitness = -1.031620487848083, Best Solution = [-0.09122138  0.71301297]
# Betina melakukan parthenogenesis.
# Generasi 44: Best Fitness = -1.0316251897168078, Best Solution = [-0.09049109  0.71224919]
# Betina kawin dengan jantan besar.
# Generasi 45: Best Fitness = -1.0316251897168078, Best Solution = [-0.09049109  0.71224919]
# Betina melakukan parthenogenesis.
# Generasi 46: Best Fitness = -1.0316283860812636, Best Solution = [-0.08973222  0.71270008]
# Betina kawin dengan jantan besar.
# Generasi 47: Best Fitness = -1.0316283860812636, Best Solution = [-0.08973222  0.71270008]
# Betina kawin dengan jantan besar.
# Generasi 48: Best Fitness = -1.0316283860812636, Best Solution = [-0.08973222  0.71270008]
# Betina melakukan parthenogenesis.
# Generasi 49: Best Fitness = -1.0316283860812636, Best Solution = [-0.08973222  0.71270008]
# Betina kawin dengan jantan besar.
# Generasi 50: Best Fitness = -1.0316284178102066, Best Solution = [-0.08993746  0.71266958]
# Betina melakukan parthenogenesis.
# Generasi 51: Best Fitness = -1.0316284178102066, Best Solution = [-0.08993746  0.71266958]
# Betina melakukan parthenogenesis.
# Generasi 52: Best Fitness = -1.0316284178102066, Best Solution = [-0.08993746  0.71266958]
# Betina kawin dengan jantan besar.
# Generasi 53: Best Fitness = -1.0316284312841568, Best Solution = [-0.08987859  0.71261303]
# Betina melakukan parthenogenesis.
# Generasi 54: Best Fitness = -1.0316284360770667, Best Solution = [-0.08989668  0.71268648]
# Betina melakukan parthenogenesis.
# Generasi 55: Best Fitness = -1.0316284461003455, Best Solution = [-0.08984658  0.71262681]
# Betina kawin dengan jantan besar.
# Generasi 56: Best Fitness = -1.031628451494829, Best Solution = [-0.08986468  0.71265873]
# Betina kawin dengan jantan besar.
# Generasi 57: Best Fitness = -1.031628451494829, Best Solution = [-0.08986468  0.71265873]
# Betina kawin dengan jantan besar.
# Generasi 58: Best Fitness = -1.031628451494829, Best Solution = [-0.08986468  0.71265873]
# Betina kawin dengan jantan besar.
# Generasi 59: Best Fitness = -1.031628451494829, Best Solution = [-0.08986468  0.71265873]
# Betina melakukan parthenogenesis.
# Generasi 60: Best Fitness = -1.0316284523424915, Best Solution = [-0.08985082  0.71264677]
# Betina kawin dengan jantan besar.
# Generasi 61: Best Fitness = -1.0316284523424915, Best Solution = [-0.08985082  0.71264677]
# Betina melakukan parthenogenesis.
# Generasi 62: Best Fitness = -1.0316284523424915, Best Solution = [-0.08985082  0.71264677]
# Betina kawin dengan jantan besar.
# Generasi 63: Best Fitness = -1.0316284524741062, Best Solution = [-0.08985598  0.71265161]
# Betina kawin dengan jantan besar.
# Generasi 64: Best Fitness = -1.0316284527254158, Best Solution = [-0.08985591  0.7126587 ]
# Betina kawin dengan jantan besar.
# Generasi 65: Best Fitness = -1.0316284527254158, Best Solution = [-0.08985591  0.7126587 ]
# Betina melakukan parthenogenesis.
# Generasi 66: Best Fitness = -1.0316284528500794, Best Solution = [-0.08985252  0.71265195]
# Betina kawin dengan jantan besar.
# Generasi 67: Best Fitness = -1.0316284529247681, Best Solution = [-0.08985399  0.71265604]
# Betina kawin dengan jantan besar.
# Generasi 68: Best Fitness = -1.0316284529247681, Best Solution = [-0.08985399  0.71265604]
# Betina melakukan parthenogenesis.
# Generasi 69: Best Fitness = -1.031628452977922, Best Solution = [-0.08985343  0.71265809]
# Betina kawin dengan jantan besar.
# Generasi 70: Best Fitness = -1.0316284529826323, Best Solution = [-0.0898528   0.71265441]
# Betina kawin dengan jantan besar.
# Generasi 71: Best Fitness = -1.0316284529826323, Best Solution = [-0.0898528   0.71265441]
# Betina kawin dengan jantan besar.
# Generasi 72: Best Fitness = -1.0316284529839785, Best Solution = [-0.08985342  0.71265653]
# Betina kawin dengan jantan besar.
# Generasi 73: Best Fitness = -1.0316284530228508, Best Solution = [-0.08985271  0.71265532]
# Betina melakukan parthenogenesis.
# Generasi 74: Best Fitness = -1.0316284531344593, Best Solution = [-0.08985156  0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 75: Best Fitness = -1.0316284532724642, Best Solution = [-0.08984852  0.71265425]
# Betina kawin dengan jantan besar.
# Generasi 76: Best Fitness = -1.0316284533874227, Best Solution = [-0.08984693  0.71265776]
# Betina melakukan parthenogenesis.
# Generasi 77: Best Fitness = -1.0316284533874227, Best Solution = [-0.08984693  0.71265776]
# Betina melakukan parthenogenesis.
# Generasi 78: Best Fitness = -1.0316284533874227, Best Solution = [-0.08984693  0.71265776]
# Betina kawin dengan jantan besar.
# Generasi 79: Best Fitness = -1.0316284533874227, Best Solution = [-0.08984693  0.71265776]
# Betina melakukan parthenogenesis.
# Generasi 80: Best Fitness = -1.0316284534059923, Best Solution = [-0.08984667  0.71265682]
# Betina melakukan parthenogenesis.
# Generasi 81: Best Fitness = -1.0316284534181965, Best Solution = [-0.08984492  0.7126544 ]
# Betina kawin dengan jantan besar.
# Generasi 82: Best Fitness = -1.0316284534393811, Best Solution = [-0.08984465  0.71265826]
# Betina melakukan parthenogenesis.
# Generasi 83: Best Fitness = -1.0316284534393811, Best Solution = [-0.08984465  0.71265826]
# Betina kawin dengan jantan besar.
# Generasi 84: Best Fitness = -1.031628453462583, Best Solution = [-0.08984462  0.7126562 ]
# Betina kawin dengan jantan besar.
# Generasi 85: Best Fitness = -1.031628453462583, Best Solution = [-0.08984462  0.7126562 ]
# Betina melakukan parthenogenesis.
# Generasi 86: Best Fitness = -1.031628453462583, Best Solution = [-0.08984462  0.7126562 ]
# Betina melakukan parthenogenesis.
# Generasi 87: Best Fitness = -1.031628453462583, Best Solution = [-0.08984462  0.7126562 ]
# Betina melakukan parthenogenesis.
# Generasi 88: Best Fitness = -1.0316284534766358, Best Solution = [-0.08984385  0.71265668]
# Betina kawin dengan jantan besar.
# Generasi 89: Best Fitness = -1.0316284534766358, Best Solution = [-0.08984385  0.71265668]
# Betina kawin dengan jantan besar.
# Generasi 90: Best Fitness = -1.031628453477072, Best Solution = [-0.08984382  0.71265665]
# Betina melakukan parthenogenesis.
# Generasi 91: Best Fitness = -1.031628453477072, Best Solution = [-0.08984382  0.71265665]
# Betina melakukan parthenogenesis.
# Generasi 92: Best Fitness = -1.0316284534797582, Best Solution = [-0.08984361  0.7126567 ]
# Betina kawin dengan jantan besar.
# Generasi 93: Best Fitness = -1.0316284534837852, Best Solution = [-0.08984324  0.71265631]
# Betina melakukan parthenogenesis.
# Generasi 94: Best Fitness = -1.0316284534856508, Best Solution = [-0.08984304  0.71265634]
# Betina kawin dengan jantan besar.
# Generasi 95: Best Fitness = -1.0316284534883096, Best Solution = [-0.08984152  0.7126561 ]
# Betina kawin dengan jantan besar.
# Generasi 96: Best Fitness = -1.0316284534883096, Best Solution = [-0.08984152  0.7126561 ]
# Betina melakukan parthenogenesis.
# Generasi 97: Best Fitness = -1.0316284534883096, Best Solution = [-0.08984152  0.7126561 ]
# Betina kawin dengan jantan besar.
# Generasi 98: Best Fitness = -1.0316284534888416, Best Solution = [-0.08984242  0.71265621]
# Betina melakukan parthenogenesis.
# Generasi 99: Best Fitness = -1.0316284534894768, Best Solution = [-0.08984217  0.71265622]
# Betina kawin dengan jantan besar.
# Generasi 100: Best Fitness = -1.0316284534894768, Best Solution = [-0.08984217  0.71265622]
# {'best_solution': array([-0.08984217,  0.71265622]),
#  'best_fitness': -1.0316284534894768,
#  'history': {'best_fitness': [0.6703083250571567,
#    0.4521671065739133,
#    -0.9003864774022448,
#    -0.9003864774022448,
#    -0.9003864774022448,
#    -0.9003864774022448,
#    -0.9003864774022448,
#    -0.9003864774022448,
#    -0.9003864774022448,
#    -1.005641888968967,
#    -1.005641888968967,
#    -1.005641888968967,
#    -1.005641888968967,
#    -1.005641888968967,
#    -1.005641888968967,
#    -1.005641888968967,
#    -1.0263619915825375,
#    -1.0263619915825375,
#    -1.0263619915825375,
#    -1.0263619915825375,
#    -1.0263619915825375,
#    -1.0263619915825375,
#    -1.0263619915825375,
#    -1.0263619915825375,
#    -1.0263619915825375,
#    -1.0263619915825375,
#    -1.0284459850683212,
#    -1.0287812921706507,
#    -1.0310543552905087,
#    -1.031160631790098,
#    -1.031160631790098,
#    -1.031160631790098,
#    -1.0315311951172308,
#    -1.0315311951172308,
#    -1.0315311951172308,
#    -1.0315311951172308,
#    -1.0315311951172308,
#    -1.031593342570998,
#    -1.0316174707088204,
#    -1.0316174707088204,
#    -1.0316174707088204,
#    -1.0316174707088204,
#    -1.031620487848083,
#    -1.0316251897168078,
#    -1.0316251897168078,
#    -1.0316283860812636,
#    -1.0316283860812636,
#    -1.0316283860812636,
#    -1.0316283860812636,
#    -1.0316284178102066,
#    -1.0316284178102066,
#    -1.0316284178102066,
#    -1.0316284312841568,
#    -1.0316284360770667,
#    -1.0316284461003455,
#    -1.031628451494829,
#    -1.031628451494829,
#    -1.031628451494829,
#    -1.031628451494829,
#    -1.0316284523424915,
#    -1.0316284523424915,
#    -1.0316284523424915,
#    -1.0316284524741062,
#    -1.0316284527254158,
#    -1.0316284527254158,
#    -1.0316284528500794,
#    -1.0316284529247681,
#    -1.0316284529247681,
#    -1.031628452977922,
#    -1.0316284529826323,
#    -1.0316284529826323,
#    -1.0316284529839785,
#    -1.0316284530228508,
#    -1.0316284531344593,
#    -1.0316284532724642,
#    -1.0316284533874227,
#    -1.0316284533874227,
#    -1.0316284533874227,
#    -1.0316284533874227,
#    -1.0316284534059923,
#    -1.0316284534181965,
#    -1.0316284534393811,
#    -1.0316284534393811,
#    -1.031628453462583,
#    -1.031628453462583,
#    -1.031628453462583,
#    -1.031628453462583,
#    -1.0316284534766358,
#    -1.0316284534766358,
#    -1.031628453477072,
#    -1.031628453477072,
#    -1.0316284534797582,
#    -1.0316284534837852,
#    -1.0316284534856508,
#    -1.0316284534883096,
#    -1.0316284534883096,
#    -1.0316284534883096,
#    -1.0316284534888416,
#    -1.0316284534894768,
#    -1.0316284534894768],
#   'best_solution': [array([-0.07442399,  1.07578836]),
#    array([ 1.45006482, -0.59330616]),
#    array([0.09277136, 0.69986156]),
#    array([0.09277136, 0.69986156]),
#    array([0.09277136, 0.69986156]),
#    array([0.09277136, 0.69986156]),
#    array([0.09277136, 0.69986156]),
#    array([0.09277136, 0.69986156]),
#    array([0.09277136, 0.69986156]),
#    array([ 0.16973859, -0.73185425]),
#    array([ 0.16973859, -0.73185425]),
#    array([ 0.16973859, -0.73185425]),
#    array([ 0.16973859, -0.73185425]),
#    array([ 0.16973859, -0.73185425]),
#    array([ 0.16973859, -0.73185425]),
#    array([ 0.16973859, -0.73185425]),
#    array([-0.09482886,  0.68739492]),
#    array([-0.09482886,  0.68739492]),
#    array([-0.09482886,  0.68739492]),
#    array([-0.09482886,  0.68739492]),
#    array([-0.09482886,  0.68739492]),
#    array([-0.09482886,  0.68739492]),
#    array([-0.09482886,  0.68739492]),
#    array([-0.09482886,  0.68739492]),
#    array([-0.09482886,  0.68739492]),
#    array([-0.09482886,  0.68739492]),
#    array([-0.07185619,  0.69601153]),
#    array([-0.07131235,  0.69775824]),
#    array([-0.09216424,  0.70453362]),
#    array([-0.0820581 ,  0.70681997]),
#    array([-0.0820581 ,  0.70681997]),
#    array([-0.0820581 ,  0.70681997]),
#    array([-0.08854465,  0.70924001]),
#    array([-0.08854465,  0.70924001]),
#    array([-0.08854465,  0.70924001]),
#    array([-0.08854465,  0.70924001]),
#    array([-0.08854465,  0.70924001]),
#    array([-0.09285148,  0.71273047]),
#    array([-0.09142523,  0.71235612]),
#    array([-0.09142523,  0.71235612]),
#    array([-0.09142523,  0.71235612]),
#    array([-0.09142523,  0.71235612]),
#    array([-0.09122138,  0.71301297]),
#    array([-0.09049109,  0.71224919]),
#    array([-0.09049109,  0.71224919]),
#    array([-0.08973222,  0.71270008]),
#    array([-0.08973222,  0.71270008]),
#    array([-0.08973222,  0.71270008]),
#    array([-0.08973222,  0.71270008]),
#    array([-0.08993746,  0.71266958]),
#    array([-0.08993746,  0.71266958]),
#    array([-0.08993746,  0.71266958]),
#    array([-0.08987859,  0.71261303]),
#    array([-0.08989668,  0.71268648]),
#    array([-0.08984658,  0.71262681]),
#    array([-0.08986468,  0.71265873]),
#    array([-0.08986468,  0.71265873]),
#    array([-0.08986468,  0.71265873]),
#    array([-0.08986468,  0.71265873]),
#    array([-0.08985082,  0.71264677]),
#    array([-0.08985082,  0.71264677]),
#    array([-0.08985082,  0.71264677]),
#    array([-0.08985598,  0.71265161]),
#    array([-0.08985591,  0.7126587 ]),
#    array([-0.08985591,  0.7126587 ]),
#    array([-0.08985252,  0.71265195]),
#    array([-0.08985399,  0.71265604]),
#    array([-0.08985399,  0.71265604]),
#    array([-0.08985343,  0.71265809]),
#    array([-0.0898528 ,  0.71265441]),
#    array([-0.0898528 ,  0.71265441]),
#    array([-0.08985342,  0.71265653]),
#    array([-0.08985271,  0.71265532]),
#    array([-0.08985156,  0.7126564 ]),
#    array([-0.08984852,  0.71265425]),
#    array([-0.08984693,  0.71265776]),
#    array([-0.08984693,  0.71265776]),
#    array([-0.08984693,  0.71265776]),
#    array([-0.08984693,  0.71265776]),
#    array([-0.08984667,  0.71265682]),
#    array([-0.08984492,  0.7126544 ]),
#    array([-0.08984465,  0.71265826]),
#    array([-0.08984465,  0.71265826]),
#    array([-0.08984462,  0.7126562 ]),
#    array([-0.08984462,  0.7126562 ]),
#    array([-0.08984462,  0.7126562 ]),
#    array([-0.08984462,  0.7126562 ]),
#    array([-0.08984385,  0.71265668]),
#    array([-0.08984385,  0.71265668]),
#    array([-0.08984382,  0.71265665]),
#    array([-0.08984382,  0.71265665]),
#    array([-0.08984361,  0.7126567 ]),
#    array([-0.08984324,  0.71265631]),
#    array([-0.08984304,  0.71265634]),
#    array([-0.08984152,  0.7126561 ]),
#    array([-0.08984152,  0.7126561 ]),
#    array([-0.08984152,  0.7126561 ]),
#    array([-0.08984242,  0.71265621]),
#    array([-0.08984217,  0.71265622]),
#    array([-0.08984217,  0.71265622])]}}
