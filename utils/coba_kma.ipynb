# %%
import numpy as np
from kma_method import KomodoMlipirAlgorithm

# %%
def fitness_function(x):
    return 4*x[0]**2 - 2.1*x[0]**4 + 1/3*x[0]**6 + x[0]*x[1] - 4*x[1]**2 + 4*x[1]**4

# %%
space_search = {
    'x1':[-5,5],
    'x2':[-5,5]
}

# %%
kma = KomodoMlipirAlgorithm(20,0.5,0.1,fitness_function,space_search,max_iter=100,problem="minimize")

# %%
kma.optimize()
# Out:
# Betina kawin dengan jantan besar.
# Generasi 1: Best Fitness = -0.7743511435026633, Best Solution = [-0.22867123  0.85642484]
# Betina kawin dengan jantan besar.
# Generasi 2: Best Fitness = -0.7743511435026633, Best Solution = [-0.22867123  0.85642484]
# Betina kawin dengan jantan besar.
# Generasi 3: Best Fitness = -0.7743511435026633, Best Solution = [-0.22867123  0.85642484]
# Betina melakukan parthenogenesis.
# Generasi 4: Best Fitness = -0.7743511435026633, Best Solution = [-0.22867123  0.85642484]
# Betina kawin dengan jantan besar.
# Generasi 5: Best Fitness = -0.7743511435026633, Best Solution = [-0.22867123  0.85642484]
# Betina melakukan parthenogenesis.
# Generasi 6: Best Fitness = -0.9650917511015947, Best Solution = [ 0.15362334 -0.63346173]
# Betina melakukan parthenogenesis.
# Generasi 7: Best Fitness = -0.9650917511015947, Best Solution = [ 0.15362334 -0.63346173]
# Betina melakukan parthenogenesis.
# Generasi 8: Best Fitness = -0.9650917511015947, Best Solution = [ 0.15362334 -0.63346173]
# Betina kawin dengan jantan besar.
# Generasi 9: Best Fitness = -0.9957054808996411, Best Solution = [ 0.07991954 -0.64273708]
# Betina kawin dengan jantan besar.
# Generasi 10: Best Fitness = -0.999792659373292, Best Solution = [ 0.05194803 -0.76511616]
# Betina melakukan parthenogenesis.
# Generasi 11: Best Fitness = -0.999792659373292, Best Solution = [ 0.05194803 -0.76511616]
# Betina kawin dengan jantan besar.
# Generasi 12: Best Fitness = -0.999792659373292, Best Solution = [ 0.05194803 -0.76511616]
# Betina kawin dengan jantan besar.
# Generasi 13: Best Fitness = -1.02934396329438, Best Solution = [ 0.08719061 -0.6956896 ]
# Betina kawin dengan jantan besar.
# Generasi 14: Best Fitness = -1.02934396329438, Best Solution = [ 0.08719061 -0.6956896 ]
# Betina kawin dengan jantan besar.
# Generasi 15: Best Fitness = -1.02934396329438, Best Solution = [ 0.08719061 -0.6956896 ]
# Betina kawin dengan jantan besar.
# Generasi 16: Best Fitness = -1.02934396329438, Best Solution = [ 0.08719061 -0.6956896 ]
# Betina kawin dengan jantan besar.
# Generasi 17: Best Fitness = -1.02934396329438, Best Solution = [ 0.08719061 -0.6956896 ]
# Betina kawin dengan jantan besar.
# Generasi 18: Best Fitness = -1.0315379955165744, Best Solution = [ 0.09176032 -0.70971674]
# Betina melakukan parthenogenesis.
# Generasi 19: Best Fitness = -1.0315379955165744, Best Solution = [ 0.09176032 -0.70971674]
# Betina kawin dengan jantan besar.
# Generasi 20: Best Fitness = -1.0315379955165744, Best Solution = [ 0.09176032 -0.70971674]
# Betina melakukan parthenogenesis.
# Generasi 21: Best Fitness = -1.0316225173884621, Best Solution = [ 0.08887676 -0.71206362]
# Betina melakukan parthenogenesis.
# Generasi 22: Best Fitness = -1.0316241081778479, Best Solution = [ 0.08926505 -0.71200983]
# Betina melakukan parthenogenesis.
# Generasi 23: Best Fitness = -1.0316241081778479, Best Solution = [ 0.08926505 -0.71200983]
# Betina kawin dengan jantan besar.
# Generasi 24: Best Fitness = -1.0316241081778479, Best Solution = [ 0.08926505 -0.71200983]
# Betina melakukan parthenogenesis.
# Generasi 25: Best Fitness = -1.0316263532775831, Best Solution = [ 0.09003419 -0.71315686]
# Betina melakukan parthenogenesis.
# Generasi 26: Best Fitness = -1.0316263532775831, Best Solution = [ 0.09003419 -0.71315686]
# Betina melakukan parthenogenesis.
# Generasi 27: Best Fitness = -1.031627491894001, Best Solution = [ 0.08946889 -0.71286088]
# Betina kawin dengan jantan besar.
# Generasi 28: Best Fitness = -1.0316282933710612, Best Solution = [ 0.09002943 -0.71261343]
# Betina melakukan parthenogenesis.
# Generasi 29: Best Fitness = -1.0316282933710612, Best Solution = [ 0.09002943 -0.71261343]
# Betina kawin dengan jantan besar.
# Generasi 30: Best Fitness = -1.0316282933710612, Best Solution = [ 0.09002943 -0.71261343]
# Betina kawin dengan jantan besar.
# Generasi 31: Best Fitness = -1.0316283908782482, Best Solution = [ 0.08977369 -0.71257846]
# Betina melakukan parthenogenesis.
# Generasi 32: Best Fitness = -1.031628422581721, Best Solution = [ 0.0898126  -0.71259659]
# Betina melakukan parthenogenesis.
# Generasi 33: Best Fitness = -1.0316284410230234, Best Solution = [ 0.08978697 -0.71264349]
# Betina kawin dengan jantan besar.
# Generasi 34: Best Fitness = -1.0316284492185428, Best Solution = [ 0.08982207 -0.71263692]
# Betina melakukan parthenogenesis.
# Generasi 35: Best Fitness = -1.0316284492185428, Best Solution = [ 0.08982207 -0.71263692]
# Betina melakukan parthenogenesis.
# Generasi 36: Best Fitness = -1.0316284492185428, Best Solution = [ 0.08982207 -0.71263692]
# Betina kawin dengan jantan besar.
# Generasi 37: Best Fitness = -1.0316284492185428, Best Solution = [ 0.08982207 -0.71263692]
# Betina kawin dengan jantan besar.
# Generasi 38: Best Fitness = -1.031628449860644, Best Solution = [ 0.08987264 -0.71265865]
# Betina melakukan parthenogenesis.
# Generasi 39: Best Fitness = -1.0316284517169514, Best Solution = [ 0.08984357 -0.71267117]
# Betina melakukan parthenogenesis.
# Generasi 40: Best Fitness = -1.0316284521368673, Best Solution = [ 0.0898407 -0.7126435]
# Betina melakukan parthenogenesis.
# Generasi 41: Best Fitness = -1.0316284531856943, Best Solution = [ 0.08984928 -0.71265335]
# Betina melakukan parthenogenesis.
# Generasi 42: Best Fitness = -1.0316284531856943, Best Solution = [ 0.08984928 -0.71265335]
# Betina melakukan parthenogenesis.
# Generasi 43: Best Fitness = -1.0316284531856943, Best Solution = [ 0.08984928 -0.71265335]
# Betina melakukan parthenogenesis.
# Generasi 44: Best Fitness = -1.0316284531856943, Best Solution = [ 0.08984928 -0.71265335]
# Betina kawin dengan jantan besar.
# Generasi 45: Best Fitness = -1.0316284531856943, Best Solution = [ 0.08984928 -0.71265335]
# Betina melakukan parthenogenesis.
# Generasi 46: Best Fitness = -1.0316284534326567, Best Solution = [ 0.08984582 -0.71265703]
# Betina kawin dengan jantan besar.
# Generasi 47: Best Fitness = -1.0316284534326567, Best Solution = [ 0.08984582 -0.71265703]
# Betina kawin dengan jantan besar.
# Generasi 48: Best Fitness = -1.0316284534326567, Best Solution = [ 0.08984582 -0.71265703]
# Betina melakukan parthenogenesis.
# Generasi 49: Best Fitness = -1.0316284534326567, Best Solution = [ 0.08984582 -0.71265703]
# Betina kawin dengan jantan besar.
# Generasi 50: Best Fitness = -1.0316284534326567, Best Solution = [ 0.08984582 -0.71265703]
# Betina melakukan parthenogenesis.
# Generasi 51: Best Fitness = -1.0316284534867457, Best Solution = [ 0.08984252 -0.71265694]
# Betina melakukan parthenogenesis.
# Generasi 52: Best Fitness = -1.0316284534867457, Best Solution = [ 0.08984252 -0.71265694]
# Betina kawin dengan jantan besar.
# Generasi 53: Best Fitness = -1.0316284534881528, Best Solution = [ 0.08984258 -0.71265668]
# Betina melakukan parthenogenesis.
# Generasi 54: Best Fitness = -1.0316284534881528, Best Solution = [ 0.08984258 -0.71265668]
# Betina melakukan parthenogenesis.
# Generasi 55: Best Fitness = -1.0316284534881528, Best Solution = [ 0.08984258 -0.71265668]
# Betina kawin dengan jantan besar.
# Generasi 56: Best Fitness = -1.0316284534881528, Best Solution = [ 0.08984258 -0.71265668]
# Betina kawin dengan jantan besar.
# Generasi 57: Best Fitness = -1.0316284534883216, Best Solution = [ 0.08984261 -0.71265628]
# Betina kawin dengan jantan besar.
# Generasi 58: Best Fitness = -1.0316284534892657, Best Solution = [ 0.08984208 -0.71265668]
# Betina kawin dengan jantan besar.
# Generasi 59: Best Fitness = -1.0316284534892657, Best Solution = [ 0.08984208 -0.71265668]
# Betina melakukan parthenogenesis.
# Generasi 60: Best Fitness = -1.0316284534895583, Best Solution = [ 0.08984173 -0.71265642]
# Betina kawin dengan jantan besar.
# Generasi 61: Best Fitness = -1.031628453489872, Best Solution = [ 0.08984199 -0.71265642]
# Betina melakukan parthenogenesis.
# Generasi 62: Best Fitness = -1.031628453489872, Best Solution = [ 0.08984199 -0.71265642]
# Betina kawin dengan jantan besar.
# Generasi 63: Best Fitness = -1.031628453489872, Best Solution = [ 0.08984199 -0.71265642]
# Betina kawin dengan jantan besar.
# Generasi 64: Best Fitness = -1.0316284534898736, Best Solution = [ 0.08984199 -0.71265641]
# Betina kawin dengan jantan besar.
# Generasi 65: Best Fitness = -1.0316284534898736, Best Solution = [ 0.08984199 -0.71265641]
# Betina melakukan parthenogenesis.
# Generasi 66: Best Fitness = -1.0316284534898736, Best Solution = [ 0.08984199 -0.71265641]
# Betina kawin dengan jantan besar.
# Generasi 67: Best Fitness = -1.0316284534898772, Best Solution = [ 0.08984202 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 68: Best Fitness = -1.0316284534898772, Best Solution = [ 0.08984202 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 69: Best Fitness = -1.0316284534898772, Best Solution = [ 0.08984202 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 70: Best Fitness = -1.0316284534898772, Best Solution = [ 0.08984202 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 71: Best Fitness = -1.0316284534898772, Best Solution = [ 0.08984202 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 72: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 73: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 74: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 75: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 76: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 77: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 78: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 79: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 80: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 81: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 82: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 83: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 84: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 85: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 86: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 87: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 88: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 89: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 90: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 91: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 92: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 93: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 94: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 95: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 96: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 97: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 98: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina melakukan parthenogenesis.
# Generasi 99: Best Fitness = -1.0316284534898776, Best Solution = [ 0.08984201 -0.7126564 ]
# Betina kawin dengan jantan besar.
# Generasi 100: Best Fitness = -1.0316284534898779, Best Solution = [ 0.08984201 -0.7126564 ]
# {'best_solution': array([ 0.08984201, -0.7126564 ]),
#  'best_fitness': -1.0316284534898779,
#  'history': {'best_fitness': [-0.7743511435026633,
#    -0.7743511435026633,
#    -0.7743511435026633,
#    -0.7743511435026633,
#    -0.7743511435026633,
#    -0.9650917511015947,
#    -0.9650917511015947,
#    -0.9650917511015947,
#    -0.9957054808996411,
#    -0.999792659373292,
#    -0.999792659373292,
#    -0.999792659373292,
#    -1.02934396329438,
#    -1.02934396329438,
#    -1.02934396329438,
#    -1.02934396329438,
#    -1.02934396329438,
#    -1.0315379955165744,
#    -1.0315379955165744,
#    -1.0315379955165744,
#    -1.0316225173884621,
#    -1.0316241081778479,
#    -1.0316241081778479,
#    -1.0316241081778479,
#    -1.0316263532775831,
#    -1.0316263532775831,
#    -1.031627491894001,
#    -1.0316282933710612,
#    -1.0316282933710612,
#    -1.0316282933710612,
#    -1.0316283908782482,
#    -1.031628422581721,
#    -1.0316284410230234,
#    -1.0316284492185428,
#    -1.0316284492185428,
#    -1.0316284492185428,
#    -1.0316284492185428,
#    -1.031628449860644,
#    -1.0316284517169514,
#    -1.0316284521368673,
#    -1.0316284531856943,
#    -1.0316284531856943,
#    -1.0316284531856943,
#    -1.0316284531856943,
#    -1.0316284531856943,
#    -1.0316284534326567,
#    -1.0316284534326567,
#    -1.0316284534326567,
#    -1.0316284534326567,
#    -1.0316284534326567,
#    -1.0316284534867457,
#    -1.0316284534867457,
#    -1.0316284534881528,
#    -1.0316284534881528,
#    -1.0316284534881528,
#    -1.0316284534881528,
#    -1.0316284534883216,
#    -1.0316284534892657,
#    -1.0316284534892657,
#    -1.0316284534895583,
#    -1.031628453489872,
#    -1.031628453489872,
#    -1.031628453489872,
#    -1.0316284534898736,
#    -1.0316284534898736,
#    -1.0316284534898736,
#    -1.0316284534898772,
#    -1.0316284534898772,
#    -1.0316284534898772,
#    -1.0316284534898772,
#    -1.0316284534898772,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898776,
#    -1.0316284534898779],
#   'best_solution': [array([-0.22867123,  0.85642484]),
#    array([-0.22867123,  0.85642484]),
#    array([-0.22867123,  0.85642484]),
#    array([-0.22867123,  0.85642484]),
#    array([-0.22867123,  0.85642484]),
#    array([ 0.15362334, -0.63346173]),
#    array([ 0.15362334, -0.63346173]),
#    array([ 0.15362334, -0.63346173]),
#    array([ 0.07991954, -0.64273708]),
#    array([ 0.05194803, -0.76511616]),
#    array([ 0.05194803, -0.76511616]),
#    array([ 0.05194803, -0.76511616]),
#    array([ 0.08719061, -0.6956896 ]),
#    array([ 0.08719061, -0.6956896 ]),
#    array([ 0.08719061, -0.6956896 ]),
#    array([ 0.08719061, -0.6956896 ]),
#    array([ 0.08719061, -0.6956896 ]),
#    array([ 0.09176032, -0.70971674]),
#    array([ 0.09176032, -0.70971674]),
#    array([ 0.09176032, -0.70971674]),
#    array([ 0.08887676, -0.71206362]),
#    array([ 0.08926505, -0.71200983]),
#    array([ 0.08926505, -0.71200983]),
#    array([ 0.08926505, -0.71200983]),
#    array([ 0.09003419, -0.71315686]),
#    array([ 0.09003419, -0.71315686]),
#    array([ 0.08946889, -0.71286088]),
#    array([ 0.09002943, -0.71261343]),
#    array([ 0.09002943, -0.71261343]),
#    array([ 0.09002943, -0.71261343]),
#    array([ 0.08977369, -0.71257846]),
#    array([ 0.0898126 , -0.71259659]),
#    array([ 0.08978697, -0.71264349]),
#    array([ 0.08982207, -0.71263692]),
#    array([ 0.08982207, -0.71263692]),
#    array([ 0.08982207, -0.71263692]),
#    array([ 0.08982207, -0.71263692]),
#    array([ 0.08987264, -0.71265865]),
#    array([ 0.08984357, -0.71267117]),
#    array([ 0.0898407, -0.7126435]),
#    array([ 0.08984928, -0.71265335]),
#    array([ 0.08984928, -0.71265335]),
#    array([ 0.08984928, -0.71265335]),
#    array([ 0.08984928, -0.71265335]),
#    array([ 0.08984928, -0.71265335]),
#    array([ 0.08984582, -0.71265703]),
#    array([ 0.08984582, -0.71265703]),
#    array([ 0.08984582, -0.71265703]),
#    array([ 0.08984582, -0.71265703]),
#    array([ 0.08984582, -0.71265703]),
#    array([ 0.08984252, -0.71265694]),
#    array([ 0.08984252, -0.71265694]),
#    array([ 0.08984258, -0.71265668]),
#    array([ 0.08984258, -0.71265668]),
#    array([ 0.08984258, -0.71265668]),
#    array([ 0.08984258, -0.71265668]),
#    array([ 0.08984261, -0.71265628]),
#    array([ 0.08984208, -0.71265668]),
#    array([ 0.08984208, -0.71265668]),
#    array([ 0.08984173, -0.71265642]),
#    array([ 0.08984199, -0.71265642]),
#    array([ 0.08984199, -0.71265642]),
#    array([ 0.08984199, -0.71265642]),
#    array([ 0.08984199, -0.71265641]),
#    array([ 0.08984199, -0.71265641]),
#    array([ 0.08984199, -0.71265641]),
#    array([ 0.08984202, -0.7126564 ]),
#    array([ 0.08984202, -0.7126564 ]),
#    array([ 0.08984202, -0.7126564 ]),
#    array([ 0.08984202, -0.7126564 ]),
#    array([ 0.08984202, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ]),
#    array([ 0.08984201, -0.7126564 ])]}}
