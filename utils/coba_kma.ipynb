# %%
import numpy as np
from kma_method import KomodoMlipirAlgorithm

# %%
def fitness_function(x):
    return 4*x[0]**2 - 2.1*x[0]**4 + 1/3*x[0]**6 + x[0]*x[1] - 4*x[1]**2 + 4*x[1]**4

# %%
space_search = {
    'x1':[-5,5],
    'x2':[-5,5]
}

# %%
kma = KomodoMlipirAlgorithm(100,0.5,0.1,fitness_function,space_search,max_iter=100,problem="minimize")

# %%
kma.optimize()
# Out:
# Betina kawin dengan jantan besar.
# Generasi 1: Best Fitness = -0.6624623192806991, Best Solution = [-0.41084224  0.68741196]
# Betina melakukan parthenogenesis.
# Generasi 2: Best Fitness = -0.6624623192806991, Best Solution = [-0.41084224  0.68741196]
# Betina kawin dengan jantan besar.
# Generasi 3: Best Fitness = -0.6624623192806991, Best Solution = [-0.41084224  0.68741196]
# Betina kawin dengan jantan besar.
# Generasi 4: Best Fitness = -0.9880092250715353, Best Solution = [-0.04982433  0.77515518]
# Betina melakukan parthenogenesis.
# Generasi 5: Best Fitness = -0.9880092250715353, Best Solution = [-0.04982433  0.77515518]
# Betina kawin dengan jantan besar.
# Generasi 6: Best Fitness = -0.9880092250715353, Best Solution = [-0.04982433  0.77515518]
# Betina melakukan parthenogenesis.
# Generasi 7: Best Fitness = -0.9880092250715353, Best Solution = [-0.04982433  0.77515518]
# Betina kawin dengan jantan besar.
# ...
